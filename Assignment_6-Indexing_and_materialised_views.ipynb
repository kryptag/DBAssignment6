# %%
# %load_ext sql

# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %%
# %sql SELECT * FROM pg_indexes WHERE tablename = 'circuits';
# Out:
# 3 rows affected.
# [('f1db', 'circuits', 'idx_17102_url', None, 'CREATE UNIQUE INDEX idx_17102_url ON circuits USING btree (url)'),
#  ('f1db', 'circuits', 'circuits_position_idx', None, 'CREATE INDEX circuits_position_idx ON circuits USING gist ("position")'),
#  ('f1db', 'circuits', 'idx_17102_primary', None, 'CREATE UNIQUE INDEX idx_17102_primary ON circuits USING btree (circuitid)')]

# %% [markdown]
# #### What type of indices exists for the table and why they are of that type (and not some other type)
#
# As seen above there are 3 different indices found in this specific table.
# first we have 2 Btree indices and 1 gist index.
#
# ###### idx_17102_url
# Is a btree because its a string that is indexed, and since btree works with simple logical operators like ">,<, =" it doesn't make sense to go for another type than btree for this index
#
# ###### idx_17102_primary
# Is a btree and it has the same reasoning behind it being a btree as `idx_17102_url`, only difference is that this index is for integers instead of strings. But again it's a simple comparison
#
# ###### circuits_position_idx
# Is a GiST the reason for choosing a GiST index here is because PostgreSQL's GiST implementation has logical operators that support two-dimensional geometric comparisons.

# %% [markdown]
# #### The amount of space each index takes up
#
#  * `idx_17102_url` takes up 16KB
#  * `idx_17102_primary` also takes up 16KB
#  * `circuits_position_idx` takes up 8192 bytes or 8,192KB
# All 3 indices size sum up to a bit over 40KB, This is actually a very small amount.

# %% [markdown]
# #### We are talent scouts looking to win over some of the best new drivers there are
# But we don't want them too old! Write a query that finds the winner of all the races, but only if they are younger than 38 years. The query should give return the date, driver surname, driver age, track time in milliseconds, race name and circuit name for all races.

# %%
# %%sql
# SELECT  races.date AS race_date,
#         milliseconds,
#         drivers.surname,
#         races.name AS race_name,
#         circuits.name AS circuit_name,
#         date_part('year', age(drivers.dob)) AS driver_age FROM results
#         JOIN drivers ON date_part('year', age(drivers.dob)) < 38
#             AND results.position = 1
#             AND drivers.driverid = results.driverid
#         JOIN races USING (raceid)
#         JOIN circuits ON circuits.circuitid = races.circuitid;
# Out:
# 184 rows affected.
# [(datetime.date(2008, 3, 16), 5690616, 'Hamilton', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 33.0),
#  (datetime.date(2008, 4, 6), 5466970, 'Massa', 'Bahrain Grand Prix', 'Bahrain International Circuit', 36.0),
#  (datetime.date(2008, 5, 11), 5209451, 'Massa', 'Turkish Grand Prix', 'Istanbul Park', 36.0),
#  (datetime.date(2008, 5, 25), 7242742, 'Hamilton', 'Monaco Grand Prix', 'Circuit de Monaco', 33.0),
#  (datetime.date(2008, 6, 8), 5784227, 'Kubica', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2008, 6, 22), 5510245, 'Massa', 'French Grand Prix', 'Circuit de Nevers Magny-Cours', 36.0),
#  (datetime.date(2008, 7, 6), 5949440, 'Hamilton', 'British Grand Prix', 'Silverstone Circuit', 33.0),
#  (datetime.date(2008, 7, 20), 5480874, 'Hamilton', 'German Grand Prix', 'Hockenheimring', 33.0),
#  (datetime.date(2008, 8, 3), 5847067, 'Kovalainen', 'Hungarian Grand Prix', 'Hungaroring', 36.0),
#  (datetime.date(2008, 8, 24), 5732339, 'Massa', 'European Grand Prix', 'Valencia Street Circuit', 36.0),
#  (datetime.date(2008, 9, 7), 4979394, 'Massa', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 36.0),
#  (datetime.date(2008, 9, 14), 5207494, 'Vettel', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 30.0),
#  (datetime.date(2008, 9, 28), 7036304, 'Alonso', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 36.0),
#  (datetime.date(2008, 10, 12), 5421892, 'Alonso', 'Japanese Grand Prix', 'Fuji Speedway', 36.0),
#  (datetime.date(2008, 10, 19), 5517403, 'Hamilton', 'Chinese Grand Prix', 'Shanghai International Circuit', 33.0),
#  (datetime.date(2008, 11, 2), 5651435, 'Massa', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 36.0),
#  (datetime.date(2007, 4, 8), 5534930, 'Alonso', 'Malaysian Grand Prix', 'Sepang International Circuit', 36.0),
#  (datetime.date(2007, 4, 15), 5607515, 'Massa', 'Bahrain Grand Prix', 'Bahrain International Circuit', 36.0),
#  (datetime.date(2007, 5, 13), 5496230, 'Massa', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 36.0),
#  (datetime.date(2007, 5, 27), 6029329, 'Alonso', 'Monaco Grand Prix', 'Circuit de Monaco', 36.0),
#  (datetime.date(2007, 6, 10), 6251292, 'Hamilton', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2007, 6, 17), 5469965, 'Hamilton', 'United States Grand Prix', 'Indianapolis Motor Speedway', 33.0),
#  (datetime.date(2007, 7, 22), 7586358, 'Alonso', 'European Grand Prix', 'Nürburgring', 36.0),
#  (datetime.date(2007, 8, 5), 5752991, 'Hamilton', 'Hungarian Grand Prix', 'Hungaroring', 33.0),
#  (datetime.date(2007, 8, 26), 5202161, 'Massa', 'Turkish Grand Prix', 'Istanbul Park', 36.0),
#  (datetime.date(2007, 9, 9), 4717806, 'Alonso', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 36.0),
#  (datetime.date(2007, 9, 30), 7234579, 'Hamilton', 'Japanese Grand Prix', 'Fuji Speedway', 33.0),
#  (datetime.date(2006, 3, 12), 5386205, 'Alonso', 'Bahrain Grand Prix', 'Bahrain International Circuit', 36.0),
#  (datetime.date(2006, 4, 2), 5667870, 'Alonso', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 36.0),
#  (datetime.date(2006, 5, 14), 5181759, 'Alonso', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 36.0),
#  (datetime.date(2006, 5, 28), 6223116, 'Alonso', 'Monaco Grand Prix', 'Circuit de Monaco', 36.0),
#  (datetime.date(2006, 6, 11), 5151927, 'Alonso', 'British Grand Prix', 'Silverstone Circuit', 36.0),
#  (datetime.date(2006, 6, 25), 5677308, 'Alonso', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 36.0),
#  (datetime.date(2006, 8, 27), 5331082, 'Massa', 'Turkish Grand Prix', 'Istanbul Park', 36.0),
#  (datetime.date(2006, 10, 8), 5032413, 'Alonso', 'Japanese Grand Prix', 'Suzuka Circuit', 36.0),
#  (datetime.date(2006, 10, 22), 5513751, 'Massa', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 36.0),
#  (datetime.date(2005, 3, 20), 5493736, 'Alonso', 'Malaysian Grand Prix', 'Sepang International Circuit', 36.0),
#  (datetime.date(2005, 4, 3), 5358531, 'Alonso', 'Bahrain Grand Prix', 'Bahrain International Circuit', 36.0),
#  (datetime.date(2005, 4, 24), 5261921, 'Alonso', 'San Marino Grand Prix', 'Autodromo Enzo e Dino Ferrari', 36.0),
#  (datetime.date(2005, 5, 29), 5506648, 'Alonso', 'European Grand Prix', 'Nürburgring', 36.0),
#  (datetime.date(2005, 7, 3), 5482232, 'Alonso', 'French Grand Prix', 'Circuit de Nevers Magny-Cours', 36.0),
#  (datetime.date(2005, 7, 24), 5188599, 'Alonso', 'German Grand Prix', 'Hockenheimring', 36.0),
#  (datetime.date(2005, 10, 16), 5993618, 'Alonso', 'Chinese Grand Prix', 'Shanghai International Circuit', 36.0),
#  (datetime.date(2003, 8, 24), 5941460, 'Alonso', 'Hungarian Grand Prix', 'Hungaroring', 36.0),
#  (datetime.date(2009, 4, 19), 7063485, 'Vettel', 'Chinese Grand Prix', 'Shanghai International Circuit', 30.0),
#  (datetime.date(2009, 6, 21), 4969328, 'Vettel', 'British Grand Prix', 'Silverstone Circuit', 30.0),
#  (datetime.date(2009, 7, 26), 5903876, 'Hamilton', 'Hungarian Grand Prix', 'Hungaroring', 33.0),
#  (datetime.date(2009, 9, 27), 6966337, 'Hamilton', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 33.0),
#  (datetime.date(2009, 10, 4), 5300443, 'Vettel', 'Japanese Grand Prix', 'Suzuka Circuit', 30.0),
#  (datetime.date(2009, 11, 1), 5643414, 'Vettel', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 30.0),
#  (datetime.date(2010, 3, 14), 5960396, 'Alonso', 'Bahrain Grand Prix', 'Bahrain International Circuit', 36.0),
#  (datetime.date(2010, 4, 4), 5628412, 'Vettel', 'Malaysian Grand Prix', 'Sepang International Circuit', 30.0),
#  (datetime.date(2010, 5, 30), 5327620, 'Hamilton', 'Turkish Grand Prix', 'Istanbul Park', 33.0),
#  (datetime.date(2010, 6, 13), 5633456, 'Hamilton', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2010, 6, 27), 6029571, 'Vettel', 'European Grand Prix', 'Valencia Street Circuit', 30.0),
#  (datetime.date(2010, 7, 25), 5258864, 'Alonso', 'German Grand Prix', 'Hockenheimring', 36.0),
#  (datetime.date(2010, 8, 29), 5344268, 'Hamilton', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 33.0),
#  (datetime.date(2010, 9, 12), 4584572, 'Alonso', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 36.0),
#  (datetime.date(2010, 9, 26), 7073579, 'Alonso', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 36.0),
#  (datetime.date(2010, 10, 10), 5427323, 'Vettel', 'Japanese Grand Prix', 'Suzuka Circuit', 30.0),
#  (datetime.date(2010, 10, 24), 10100810, 'Alonso', 'Korean Grand Prix', 'Korean International Circuit', 36.0),
#  (datetime.date(2010, 11, 7), 5591803, 'Vettel', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 30.0),
#  (datetime.date(2010, 11, 14), 5976837, 'Vettel', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 30.0),
#  (datetime.date(2011, 3, 27), 5370259, 'Vettel', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 30.0),
#  (datetime.date(2011, 4, 10), 5859832, 'Vettel', 'Malaysian Grand Prix', 'Sepang International Circuit', 30.0),
#  (datetime.date(2011, 4, 17), 5818226, 'Hamilton', 'Chinese Grand Prix', 'Shanghai International Circuit', 33.0),
#  (datetime.date(2011, 5, 8), 5417558, 'Vettel', 'Turkish Grand Prix', 'Istanbul Park', 30.0),
#  (datetime.date(2011, 5, 22), 5943301, 'Vettel', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 30.0),
#  (datetime.date(2011, 5, 29), 7778373, 'Vettel', 'Monaco Grand Prix', 'Circuit de Monaco', 30.0),
#  (datetime.date(2011, 6, 26), 5976169, 'Vettel', 'European Grand Prix', 'Valencia Street Circuit', 30.0),
#  (datetime.date(2011, 7, 10), 5321196, 'Alonso', 'British Grand Prix', 'Silverstone Circuit', 36.0),
#  (datetime.date(2011, 7, 24), 5850334, 'Hamilton', 'German Grand Prix', 'Nürburgring', 33.0),
#  (datetime.date(2011, 8, 28), 5204893, 'Vettel', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 30.0),
#  (datetime.date(2011, 9, 11), 4846172, 'Vettel', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 30.0),
#  (datetime.date(2011, 9, 25), 7146757, 'Vettel', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 30.0),
#  (datetime.date(2011, 10, 16), 5881994, 'Vettel', 'Korean Grand Prix', 'Korean International Circuit', 30.0),
#  (datetime.date(2011, 10, 30), 5435002, 'Vettel', 'Indian Grand Prix', 'Buddh International Circuit', 30.0),
#  (datetime.date(2011, 11, 13), 5831886, 'Hamilton', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 33.0),
#  (datetime.date(2012, 3, 25), 9891812, 'Alonso', 'Malaysian Grand Prix', 'Sepang International Circuit', 36.0),
#  (datetime.date(2012, 4, 15), 5786929, 'Rosberg', 'Chinese Grand Prix', 'Shanghai International Circuit', 32.0),
#  (datetime.date(2012, 4, 22), 5710990, 'Vettel', 'Bahrain Grand Prix', 'Bahrain International Circuit', 30.0),
#  (datetime.date(2012, 5, 13), 5949145, 'Maldonado', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 33.0),
#  (datetime.date(2012, 6, 10), 5549586, 'Hamilton', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2012, 6, 24), 6256649, 'Alonso', 'European Grand Prix', 'Valencia Street Circuit', 36.0),
#  (datetime.date(2012, 7, 22), 5465862, 'Alonso', 'German Grand Prix', 'Hockenheimring', 36.0),
#  (datetime.date(2012, 7, 29), 6065503, 'Hamilton', 'Hungarian Grand Prix', 'Hungaroring', 33.0),
#  (datetime.date(2012, 9, 9), 4781221, 'Hamilton', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 33.0),
#  (datetime.date(2012, 9, 23), 7226144, 'Vettel', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 30.0),
#  (datetime.date(2012, 10, 7), 5336242, 'Vettel', 'Japanese Grand Prix', 'Suzuka Circuit', 30.0),
#  (datetime.date(2012, 10, 14), 5788651, 'Vettel', 'Korean Grand Prix', 'Korean International Circuit', 30.0),
#  (datetime.date(2012, 10, 28), 5470744, 'Vettel', 'Indian Grand Prix', 'Buddh International Circuit', 30.0),
#  (datetime.date(2012, 11, 18), 5755269, 'Hamilton', 'United States Grand Prix', 'Circuit of the Americas', 33.0),
#  (datetime.date(2013, 3, 24), 5936681, 'Vettel', 'Malaysian Grand Prix', 'Sepang International Circuit', 30.0),
#  (datetime.date(2013, 4, 14), 5786945, 'Alonso', 'Chinese Grand Prix', 'Shanghai International Circuit', 36.0),
#  (datetime.date(2013, 4, 21), 5760498, 'Vettel', 'Bahrain Grand Prix', 'Bahrain International Circuit', 30.0),
#  (datetime.date(2013, 5, 12), 5956596, 'Alonso', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 36.0),
#  (datetime.date(2013, 5, 26), 8272056, 'Rosberg', 'Monaco Grand Prix', 'Circuit de Monaco', 32.0),
#  (datetime.date(2013, 6, 9), 5529143, 'Vettel', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 30.0),
#  (datetime.date(2013, 6, 30), 5579456, 'Rosberg', 'British Grand Prix', 'Silverstone Circuit', 32.0),
#  (datetime.date(2013, 7, 7), 6074711, 'Vettel', 'German Grand Prix', 'Nürburgring', 30.0),
#  (datetime.date(2013, 7, 28), 6149445, 'Hamilton', 'Hungarian Grand Prix', 'Hungaroring', 33.0),
#  (datetime.date(2013, 8, 25), 5022196, 'Vettel', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 30.0),
#  (datetime.date(2013, 9, 8), 4713352, 'Vettel', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 30.0),
#  (datetime.date(2013, 9, 22), 7153132, 'Vettel', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 30.0),
#  (datetime.date(2013, 10, 6), 6193701, 'Vettel', 'Korean Grand Prix', 'Korean International Circuit', 30.0),
#  (datetime.date(2013, 10, 13), 5209301, 'Vettel', 'Japanese Grand Prix', 'Suzuka Circuit', 30.0),
#  (datetime.date(2013, 10, 27), 5472187, 'Vettel', 'Indian Grand Prix', 'Buddh International Circuit', 30.0),
#  (datetime.date(2013, 11, 3), 5886106, 'Vettel', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 30.0),
#  (datetime.date(2013, 11, 17), 5957148, 'Vettel', 'United States Grand Prix', 'Circuit of the Americas', 30.0),
#  (datetime.date(2013, 11, 24), 5556300, 'Vettel', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 30.0),
#  (datetime.date(2014, 3, 16), 5578710, 'Rosberg', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 32.0),
#  (datetime.date(2014, 3, 30), 6025974, 'Hamilton', 'Malaysian Grand Prix', 'Sepang International Circuit', 33.0),
#  (datetime.date(2014, 4, 6), 5982743, 'Hamilton', 'Bahrain Grand Prix', 'Bahrain International Circuit', 33.0),
#  (datetime.date(2014, 4, 20), 5608338, 'Hamilton', 'Chinese Grand Prix', 'Shanghai International Circuit', 33.0),
#  (datetime.date(2014, 5, 11), 6065155, 'Hamilton', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 33.0),
#  (datetime.date(2014, 5, 25), 6567661, 'Rosberg', 'Monaco Grand Prix', 'Circuit de Monaco', 32.0),
#  (datetime.date(2014, 6, 8), 5952830, 'Ricciardo', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 28.0),
#  (datetime.date(2014, 6, 22), 5274976, 'Rosberg', 'Austrian Grand Prix', 'Red Bull Ring', 32.0),
#  (datetime.date(2014, 7, 6), 8812094, 'Hamilton', 'British Grand Prix', 'Silverstone Circuit', 33.0),
#  (datetime.date(2014, 7, 20), 5622914, 'Rosberg', 'German Grand Prix', 'Hockenheimring', 32.0),
#  (datetime.date(2014, 7, 27), 6785058, 'Ricciardo', 'Hungarian Grand Prix', 'Hungaroring', 28.0),
#  (datetime.date(2014, 8, 24), 5076556, 'Ricciardo', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 28.0),
#  (datetime.date(2014, 9, 7), 4750236, 'Hamilton', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 33.0),
#  (datetime.date(2014, 9, 21), 7204795, 'Hamilton', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 33.0),
#  (datetime.date(2014, 10, 5), 6703021, 'Hamilton', 'Japanese Grand Prix', 'Suzuka Circuit', 33.0),
#  (datetime.date(2014, 10, 12), 5510744, 'Hamilton', 'Russian Grand Prix', 'Sochi Autodrom', 33.0),
#  (datetime.date(2014, 11, 2), 6004785, 'Hamilton', 'United States Grand Prix', 'Circuit of the Americas', 33.0),
#  (datetime.date(2014, 11, 9), 5402555, 'Rosberg', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 32.0),
#  (datetime.date(2014, 11, 23), 5942619, 'Hamilton', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 33.0),
#  (datetime.date(2015, 3, 15), 5514067, 'Hamilton', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 33.0),
#  (datetime.date(2015, 3, 29), 6065793, 'Vettel', 'Malaysian Grand Prix', 'Sepang International Circuit', 30.0),
#  (datetime.date(2015, 4, 12), 5982008, 'Hamilton', 'Chinese Grand Prix', 'Shanghai International Circuit', 33.0),
#  (datetime.date(2015, 4, 19), 5705809, 'Hamilton', 'Bahrain Grand Prix', 'Bahrain International Circuit', 33.0),
#  (datetime.date(2015, 5, 10), 6072555, 'Rosberg', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 32.0),
#  (datetime.date(2015, 5, 24), 6558420, 'Rosberg', 'Monaco Grand Prix', 'Circuit de Monaco', 32.0),
#  (datetime.date(2015, 6, 7), 5513145, 'Hamilton', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2015, 6, 21), 5416930, 'Rosberg', 'Austrian Grand Prix', 'Red Bull Ring', 32.0),
#  (datetime.date(2015, 7, 5), 5487729, 'Hamilton', 'British Grand Prix', 'Silverstone Circuit', 33.0),
#  (datetime.date(2015, 7, 26), 6369985, 'Vettel', 'Hungarian Grand Prix', 'Hungaroring', 30.0),
#  (datetime.date(2015, 8, 23), 5020387, 'Hamilton', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 33.0),
#  (datetime.date(2015, 9, 6), 4680688, 'Hamilton', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 33.0),
#  (datetime.date(2015, 9, 20), 7282118, 'Vettel', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 30.0),
#  (datetime.date(2015, 9, 27), None, 'Hamilton', 'Japanese Grand Prix', 'Suzuka Circuit', 33.0),
#  (datetime.date(2015, 10, 11), 5831024, 'Hamilton', 'Russian Grand Prix', 'Sochi Autodrom', 33.0),
#  (datetime.date(2015, 10, 25), 6652703, 'Hamilton', 'United States Grand Prix', 'Circuit of the Americas', 33.0),
#  (datetime.date(2015, 11, 1), 6155038, 'Rosberg', 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez', 32.0),
#  (datetime.date(2015, 11, 15), 5469090, 'Rosberg', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 32.0),
#  (datetime.date(2015, 11, 29), 5910175, 'Rosberg', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 32.0),
#  (datetime.date(2016, 3, 20), 6495565, 'Rosberg', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 32.0),
#  (datetime.date(2016, 4, 3), 5614696, 'Rosberg', 'Bahrain Grand Prix', 'Bahrain International Circuit', 32.0),
#  (datetime.date(2016, 4, 17), 5933891, 'Rosberg', 'Chinese Grand Prix', 'Shanghai International Circuit', 32.0),
#  (datetime.date(2016, 5, 1), 5561997, 'Rosberg', 'Russian Grand Prix', 'Sochi Autodrom', 32.0),
#  (datetime.date(2016, 5, 15), 6100017, 'Verstappen', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 20.0),
#  (datetime.date(2016, 5, 29), 7169133, 'Hamilton', 'Monaco Grand Prix', 'Circuit de Monaco', 33.0),
#  (datetime.date(2016, 6, 12), 5465296, 'Hamilton', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2016, 6, 19), 5572366, 'Rosberg', 'European Grand Prix', 'Baku City Circuit', 32.0),
#  (datetime.date(2016, 7, 3), 5258107, 'Hamilton', 'Austrian Grand Prix', 'Red Bull Ring', 33.0),
#  (datetime.date(2016, 7, 10), 5695831, 'Hamilton', 'British Grand Prix', 'Silverstone Circuit', 33.0),
#  (datetime.date(2016, 7, 24), 6030115, 'Hamilton', 'Hungarian Grand Prix', 'Hungaroring', 33.0),
#  (datetime.date(2016, 7, 31), 5444200, 'Hamilton', 'German Grand Prix', 'Hockenheimring', 33.0),
#  (datetime.date(2016, 8, 28), 6291058, 'Rosberg', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 32.0),
#  (datetime.date(2016, 9, 4), 4648089, 'Rosberg', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 32.0),
#  (datetime.date(2016, 9, 18), 6948950, 'Rosberg', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 32.0),
#  (datetime.date(2016, 10, 2), 5832776, 'Ricciardo', 'Malaysian Grand Prix', 'Sepang International Circuit', 28.0),
#  (datetime.date(2016, 10, 9), 5203333, 'Rosberg', 'Japanese Grand Prix', 'Suzuka Circuit', 32.0),
#  (datetime.date(2016, 10, 23), 5892618, 'Hamilton', 'United States Grand Prix', 'Circuit of the Americas', 33.0),
#  (datetime.date(2016, 10, 30), 6031402, 'Hamilton', 'Mexican Grand Prix', 'Autódromo Hermanos Rodríguez', 33.0),
#  (datetime.date(2016, 11, 13), 10861335, 'Hamilton', 'Brazilian Grand Prix', 'Autódromo José Carlos Pace', 33.0),
#  (datetime.date(2016, 11, 27), 5884013, 'Hamilton', 'Abu Dhabi Grand Prix', 'Yas Marina Circuit', 33.0),
#  (datetime.date(2017, 3, 26), 5051672, 'Vettel', 'Australian Grand Prix', 'Albert Park Grand Prix Circuit', 30.0),
#  (datetime.date(2017, 4, 9), 5856158, 'Hamilton', 'Chinese Grand Prix', 'Shanghai International Circuit', 33.0),
#  (datetime.date(2017, 4, 16), 5633374, 'Vettel', 'Bahrain Grand Prix', 'Bahrain International Circuit', 30.0),
#  (datetime.date(2017, 4, 30), 5288743, 'Bottas', 'Russian Grand Prix', 'Sochi Autodrom', 28.0),
#  (datetime.date(2017, 5, 14), 5756497, 'Hamilton', 'Spanish Grand Prix', 'Circuit de Barcelona-Catalunya', 33.0),
#  (datetime.date(2017, 5, 28), 6284340, 'Vettel', 'Monaco Grand Prix', 'Circuit de Monaco', 30.0),
#  (datetime.date(2017, 6, 11), 5585154, 'Hamilton', 'Canadian Grand Prix', 'Circuit Gilles Villeneuve', 33.0),
#  (datetime.date(2017, 6, 25), 7435573, 'Ricciardo', 'Azerbaijan Grand Prix', 'Baku City Circuit', 28.0),
#  (datetime.date(2017, 7, 9), 4908523, 'Bottas', 'Austrian Grand Prix', 'Red Bull Ring', 28.0),
#  (datetime.date(2017, 7, 16), 4887430, 'Hamilton', 'British Grand Prix', 'Silverstone Circuit', 33.0),
#  (datetime.date(2017, 7, 30), 5986713, 'Vettel', 'Hungarian Grand Prix', 'Hungaroring', 30.0),
#  (datetime.date(2017, 8, 27), 5082820, 'Hamilton', 'Belgian Grand Prix', 'Circuit de Spa-Francorchamps', 33.0),
#  (datetime.date(2017, 9, 3), 4532312, 'Hamilton', 'Italian Grand Prix', 'Autodromo Nazionale di Monza', 33.0),
#  (datetime.date(2017, 9, 17), 7403544, 'Hamilton', 'Singapore Grand Prix', 'Marina Bay Street Circuit', 33.0),
#  (datetime.date(2017, 10, 1), 5401290, 'Verstappen', 'Malaysian Grand Prix', 'Sepang International Circuit', 20.0)]

# %%
# %%sql
# EXPLAIN ANALYZE
# SELECT  races.date AS race_date,
#         milliseconds,
#         drivers.surname,
#         races.name AS race_name,
#         circuits.name AS circuit_name,
#         date_part('year', age(drivers.dob)) AS driver_age FROM results
#         JOIN drivers ON date_part('year', age(drivers.dob)) < 38
#             AND results.position = 1
#             AND drivers.driverid = results.driverid
#         JOIN races USING (raceid)
#         JOIN circuits ON circuits.circuitid = races.circuitid;
# Out:
# 22 rows affected.
# [('Hash Join  (cost=82.13..815.57 rows=324 width=66) (actual time=1.066..4.306 rows=184 loops=1)',),
#  ('  Hash Cond: (races.circuitid = circuits.circuitid)',),
#  ('  ->  Hash Join  (cost=78.48..803.83 rows=324 width=50) (actual time=0.895..4.022 rows=184 loops=1)',),
#  ('        Hash Cond: (results.raceid = races.raceid)',),
#  ('        ->  Hash Join  (cost=38.53..759.78 rows=324 width=27) (actual time=0.564..3.650 rows=184 loops=1)',),
#  ('              Hash Cond: (results.driverid = drivers.driverid)',),
#  ('              ->  Seq Scan on results  (cost=0.00..708.96 rows=974 width=24) (actual time=0.004..2.886 rows=974 loops=1)',),
#  ('                    Filter: ("position" = 1)',),
#  ('                    Rows Removed by Filter: 22703',),
#  ('              ->  Hash  (cost=35.03..35.03 rows=280 width=19) (actual time=0.552..0.552 rows=60 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 12kB',),
#  ('                    ->  Seq Scan on drivers  (cost=0.00..35.03 rows=280 width=19) (actual time=0.010..0.536 rows=60 loops=1)',),
#  ("                          Filter: (date_part('year'::text, age((CURRENT_DATE)::timestamp with time zone, (dob)::timestamp with time zone)) < '38'::double precision)",),
#  ('                          Rows Removed by Filter: 781',),
#  ('        ->  Hash  (cost=27.76..27.76 rows=976 width=39) (actual time=0.322..0.322 rows=976 loops=1)',),
#  ('              Buckets: 1024  Batches: 1  Memory Usage: 79kB',),
#  ('              ->  Seq Scan on races  (cost=0.00..27.76 rows=976 width=39) (actual time=0.006..0.155 rows=976 loops=1)',),
#  ('  ->  Hash  (cost=2.73..2.73 rows=73 width=28) (actual time=0.110..0.110 rows=73 loops=1)',),
#  ('        Buckets: 1024  Batches: 1  Memory Usage: 13kB',),
#  ('        ->  Seq Scan on circuits  (cost=0.00..2.73 rows=73 width=28) (actual time=0.076..0.089 rows=73 loops=1)',),
#  ('Planning time: 0.620 ms',),
#  ('Execution time: 4.394 ms',)]

# %% [markdown]
# #### Describe the query using ``EXPLAIN ANALYZE``
#
# ###### How many calls are you making?
# There is being made 10 function calls before this query is done.
# First it starts by joining the 3 different tables on the cinditions i have set.
#  * Hash Cond: (races.circuitid = circuits.circuitid)
#  * Hash Cond: (results.raceid = races.raceid)
#  * Hash Cond: (results.driverid = drivers.driverid)
# When these 3 steps are done it runs a scan on the resultset. then it runs the Filter function on the result set and removes all results where position isn't equal to 1, we only want first place for each race.
#
# after this it runs a scan on the drivers where we filter for age, we don't want anybody that is older than 38 years old. And after the filter function is done it removes the drivers who are older than 38 from the resultset and returns a new resultset.
#
# Then lastly it runs a scan on both the `races` table and `circuits` to get the values that match our resultset.
#
# ###### How long does it take to perform the query?
#
# The query had a Planning time of `0.620 ms`
# and a Execution time of `4.394 ms`.

# %%
# %%sql
# CREATE MATERIALIZED VIEW race_winners_underage_38 AS
# SELECT  races.date AS race_date,
#         milliseconds,
#         drivers.surname,
#         races.name AS race_name,
#         circuits.name AS circuit_name,
#         date_part('year', age(drivers.dob)) AS driver_age FROM results
#         JOIN drivers ON date_part('year', age(drivers.dob)) < 38
#             AND results.position = 1
#             AND drivers.driverid = results.driverid
#         JOIN races USING (raceid)
#         JOIN circuits ON circuits.circuitid = races.circuitid;
# Out:
# 184 rows affected.
# []

# %%
# %sql EXPLAIN ANALYZE SELECT * FROM race_winners_underage_38;
# Out:
# 3 rows affected.
# [('Seq Scan on race_winners_underage_38  (cost=0.00..10.50 rows=50 width=1568) (actual time=0.012..0.038 rows=184 loops=1)',),
#  ('Planning time: 0.170 ms',),
#  ('Execution time: 0.104 ms',)]

# %% [markdown]
# #### Create a materialized view of your query. Using ``EXPLAIN ANALYZE`` try to query the view.
#
# The Planning time is `0.170 ms` Where before it was `0.620 ms`.
# The Execution time is `0.104 ms` Where before it was `4.394 ms`.
#
# From the look of the time it takes to get the result one would say that Views are better, but the problem with views is that it's basicly a snapshot of the resultset from when the view was created. This means if the database was updated the view would still return the same as it did before the update. So if you want the newest data at all times and want to make sure that you get it, it could make sense to run the query each time. But if it's data that rarely changes you can create a view.
